# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_thread = pd.read_csv("stress_test_results_thread.csv")
data_process = pd.read_csv("stress_test_results_process.csv")

# %%
data_thread
# Out:
#    operation  file_size_mb  client_pool_size  server_pool_size executor_type  \
# 0       list            10                 1                 1        thread
# 1       list            10                 5                 1        thread
# 2       list            10                50                 1        thread
# 3       list            50                 1                 1        thread
# 4       list            50                 5                 1        thread
# ..       ...           ...               ...               ...           ...
# 76    upload            50                 5                50        thread
# 77    upload            50                50                50        thread
# 78    upload           100                 1                50        thread
# 79    upload           100                 5                50        thread
# 80    upload           100                50                50        thread
#
# ...

# %%
data_process
# Out:
#    operation  file_size_mb  client_pool_size  server_pool_size executor_type  \
# 0       list            10                 1                 1       process
# 1       list            10                 5                 1       process
# 2       list            10                50                 1       process
# 3       list            50                 1                 1       process
# 4       list            50                 5                 1       process
# ..       ...           ...               ...               ...           ...
# 76    upload            50                 5                50       process
# 77    upload            50                50                50       process
# 78    upload           100                 1                50       process
# 79    upload           100                 5                50       process
# 80    upload           100                50                50       process
#
# ...

# %%
data =  pd.concat([data_process, data_thread])

# %%
file_path = 'combined_output.csv'
data.to_csv(file_path, index=False)

# %%
data
# Out:
#    operation  file_size_mb  client_pool_size  server_pool_size executor_type  \
# 0       list            10                 1                 1       process
# 1       list            10                 5                 1       process
# 2       list            10                50                 1       process
# 3       list            50                 1                 1       process
# 4       list            50                 5                 1       process
# ..       ...           ...               ...               ...           ...
# 76    upload            50                 5                50        thread
# 77    upload            50                50                50        thread
# 78    upload           100                 1                50        thread
# 79    upload           100                 5                50        thread
# 80    upload           100                50                50        thread
#
# ...

# %%
df = data

# %%
# Drop rows where operation is 'list'
df = df[df['operation'] != 'list']

# %%
# Ganti 'process' dengan 'thread' untuk grafik lainnya
selected_executor = 'process'

# Filter berdasarkan executor_type
df_filtered = df[df['executor_type'] == selected_executor]

# Tambahkan kolom throughput rata-rata manual
df_filtered['mean_throughput'] = df_filtered[
    ['avg_throughput', 'median_throughput', 'min_throughput', 'max_throughput']
].mean(axis=1)

# Group by file_size_mb dan operation
summary = df_filtered.groupby(['file_size_mb', 'operation'])['mean_throughput'].mean().reset_index()

# Plot
plt.figure(figsize=(10, 6))
for op in summary['operation'].unique():
    data_op = summary[summary['operation'] == op]
    plt.plot(data_op['file_size_mb'], data_op['mean_throughput'], marker='o', label=op)

plt.title(f'Average Throughput by File Size and Operation\nExecutor: {selected_executor}')
plt.xlabel('File Size (MB)')
plt.ylabel('Average Throughput')
plt.grid(True)
plt.legend(title='Operation')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_729/1937674928.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['mean_throughput'] = df_filtered[

# %%
selected_executor = 'thread'

# Filter berdasarkan executor_type
df_filtered = df[df['executor_type'] == selected_executor]

# Tambahkan kolom throughput rata-rata manual
df_filtered['mean_throughput'] = df_filtered[
    ['avg_throughput', 'median_throughput', 'min_throughput', 'max_throughput']
].mean(axis=1)

# Group by file_size_mb dan operation
summary = df_filtered.groupby(['file_size_mb', 'operation'])['mean_throughput'].mean().reset_index()

# Plot
plt.figure(figsize=(10, 6))
for op in summary['operation'].unique():
    data_op = summary[summary['operation'] == op]
    plt.plot(data_op['file_size_mb'], data_op['mean_throughput'], marker='o', label=op)

plt.title(f'Average Throughput by File Size and Operation\nExecutor: {selected_executor}')
plt.xlabel('File Size (MB)')
plt.ylabel('Average Throughput')
plt.grid(True)
plt.legend(title='Operation')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_729/3348477801.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['mean_throughput'] = df_filtered[

# %%
# Ganti ke 'thread' untuk grafik kedua
selected_executor = 'process'

# Filter data berdasarkan executor_type
df_filtered = df[df['executor_type'] == selected_executor]

# Hitung rata-rata durasi dari 4 kolom duration
df_filtered['mean_duration'] = df_filtered[
    ['avg_duration', 'median_duration', 'min_duration', 'max_duration']
].mean(axis=1)

# Group berdasarkan client_pool_size dan operation
duration_summary = df_filtered.groupby(['client_pool_size', 'operation'])['mean_duration'].mean().reset_index()

# Plot
plt.figure(figsize=(10, 6))
for op in duration_summary['operation'].unique():
    data_op = duration_summary[duration_summary['operation'] == op]
    plt.plot(data_op['client_pool_size'], data_op['mean_duration'], marker='o', label=op)

plt.title(f'Average Duration by Client Pool Size and Operation\nExecutor: {selected_executor}')
plt.xlabel('Client Pool Size')
plt.ylabel('Average Duration (seconds)')
plt.grid(True)
plt.legend(title='Operation')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_729/1185314184.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['mean_duration'] = df_filtered[

# %%
# Ganti ke 'thread' untuk grafik kedua
selected_executor = 'thread'

# Filter data berdasarkan executor_type
df_filtered = df[df['executor_type'] == selected_executor]

# Hitung rata-rata durasi dari 4 kolom duration
df_filtered['mean_duration'] = df_filtered[
    ['avg_duration', 'median_duration', 'min_duration', 'max_duration']
].mean(axis=1)

# Group berdasarkan client_pool_size dan operation
duration_summary = df_filtered.groupby(['client_pool_size', 'operation'])['mean_duration'].mean().reset_index()

# Plot
plt.figure(figsize=(10, 6))
for op in duration_summary['operation'].unique():
    data_op = duration_summary[duration_summary['operation'] == op]
    plt.plot(data_op['client_pool_size'], data_op['mean_duration'], marker='o', label=op)

plt.title(f'Average Duration by Client Pool Size and Operation\nExecutor: {selected_executor}')
plt.xlabel('Client Pool Size')
plt.ylabel('Average Duration (seconds)')
plt.grid(True)
plt.legend(title='Operation')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_729/2102668122.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['mean_duration'] = df_filtered[

# %%
# Ganti 'process' dengan 'thread' untuk grafik lainnya
selected_executor = 'process'

# Filter berdasarkan executor_type
df_filtered = df[df['executor_type'] == selected_executor]

# Hitung kolom mean_throughput
df_filtered['mean_throughput'] = df_filtered[
    ['avg_throughput', 'median_throughput', 'min_throughput', 'max_throughput']
].mean(axis=1)

# Group berdasarkan server_pool_size dan file_size_mb
throughput_summary = df_filtered.groupby(['server_pool_size', 'file_size_mb'])['mean_throughput'].mean().reset_index()

# Plot
plt.figure(figsize=(10, 6))

for server_pool in sorted(throughput_summary['server_pool_size'].unique()):
    group = throughput_summary[throughput_summary['server_pool_size'] == server_pool]
    plt.plot(group['file_size_mb'], group['mean_throughput'], marker='o', label=f'Server Pool {server_pool}')

plt.title(f'Average Throughput by Server Pool Size and File Size\nExecutor: {selected_executor}')
plt.xlabel('File Size (MB)')
plt.ylabel('Average Throughput')
plt.grid(True)
plt.legend(title='Server Pool Size')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_729/3940492516.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['mean_throughput'] = df_filtered[

# %%
# Ganti 'process' dengan 'thread' untuk grafik lainnya
selected_executor = 'thread'

# Filter berdasarkan executor_type
df_filtered = df[df['executor_type'] == selected_executor]

# Hitung kolom mean_throughput
df_filtered['mean_throughput'] = df_filtered[
    ['avg_throughput', 'median_throughput', 'min_throughput', 'max_throughput']
].mean(axis=1)

# Group berdasarkan server_pool_size dan file_size_mb
throughput_summary = df_filtered.groupby(['server_pool_size', 'file_size_mb'])['mean_throughput'].mean().reset_index()

# Plot
plt.figure(figsize=(10, 6))

for server_pool in sorted(throughput_summary['server_pool_size'].unique()):
    group = throughput_summary[throughput_summary['server_pool_size'] == server_pool]
    plt.plot(group['file_size_mb'], group['mean_throughput'], marker='o', label=f'Server Pool {server_pool}')

plt.title(f'Average Throughput by Server Pool Size and File Size\nExecutor: {selected_executor}')
plt.xlabel('File Size (MB)')
plt.ylabel('Average Throughput')
plt.grid(True)
plt.legend(title='Server Pool Size')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_729/1592694814.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['mean_throughput'] = df_filtered[

# %%
df['success_count'] = df['success_count'].where(df['success_count'] != 0, df['client_pool_size'])
# Out:
# /tmp/ipykernel_729/3646351152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['success_count'] = df['success_count'].where(df['success_count'] != 0, df['client_pool_size'])

# %%
df
# Out:
#    operation  file_size_mb  client_pool_size  server_pool_size executor_type  \
# 9   download            10                 1                 1       process
# 10  download            10                 5                 1       process
# 11  download            10                50                 1       process
# 12  download            50                 1                 1       process
# 13  download            50                 5                 1       process
# ..       ...           ...               ...               ...           ...
# 76    upload            50                 5                50        thread
# 77    upload            50                50                50        thread
# 78    upload           100                 1                50        thread
# 79    upload           100                 5                50        thread
# 80    upload           100                50                50        thread
#
# ...

# %%
import seaborn as sns
# Hitung success rate
df['success_rate'] = df['success_count'] / (df['success_count'] + df['fail_count'])

# Group by operation dan executor_type
success_summary = df.groupby(['operation', 'executor_type'])['success_rate'].mean().reset_index()

# Visualisasi
plt.figure(figsize=(8, 5))
sns.barplot(data=success_summary, x='operation', y='success_rate', hue='executor_type')

plt.title('Success Rate by Operation and Executor Type')
plt.ylabel('Success Rate')
plt.ylim(0, 1.5)
plt.xlabel('Operation')
plt.legend(title='Executor Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_729/472063809.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['success_rate'] = df['success_count'] / (df['success_count'] + df['fail_count'])

# %%
df.to_csv("combined_output.csv")

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#     operation  file_size_mb  client_pool_size  server_pool_size executor_type  \
# 0    download            10                 1                 1       process
# 1    download            10                 5                 1       process
# 2    download            10                50                 1       process
# 3    download            50                 1                 1       process
# 4    download            50                 5                 1       process
# ..        ...           ...               ...               ...           ...
# 103    upload            50                 5                50        thread
# 104    upload            50                50                50        thread
# 105    upload           100                 1                50        thread
# 106    upload           100                 5                50        thread
# 107    upload           100                50                50        thread
#
# ...

# %%
df.to_csv("combined_output.csv")

# %%
throughput_summary = df.groupby('operation').apply(
    lambda g: g['file_size_mb'].sum() / g['avg_duration'].sum()
).reset_index(name='average_throughput_MBps')

print(throughput_summary)
# Out:
#   operation  average_throughput_MBps
# 0  download                 2.580535
# 1    upload                 1.908307
# /tmp/ipykernel_729/2780950819.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   throughput_summary = df.groupby('operation').apply(

# %%
# Group by client_pool_size and compute average throughput in MB/s
throughput_by_pool = df.groupby('client_pool_size').apply(
    lambda g: g['file_size_mb'].sum() / g['avg_duration'].sum()
).reset_index(name='average_throughput_MBps')

print(throughput_by_pool)
# Out:
#    client_pool_size  average_throughput_MBps
# 0                 1                19.645287
# 1                 5                 6.745735
# 2                50                 0.856042
# /tmp/ipykernel_729/3799464022.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   throughput_by_pool = df.groupby('client_pool_size').apply(

# %%
# Group by client_pool_size and compute average throughput in MB/s
throughput_by_pool = df.groupby('server_pool_size').apply(
    lambda g: g['file_size_mb'].sum() / g['avg_duration'].sum()
).reset_index(name='average_throughput_MBps')

print(throughput_by_pool)
# Out:
#    server_pool_size  average_throughput_MBps
# 0                 1                 1.941808
# 1                 5                 2.953306
# 2                50                 1.946570
# /tmp/ipykernel_729/649234942.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   throughput_by_pool = df.groupby('server_pool_size').apply(

# %%
throughput_by_executor = df.groupby('executor_type').apply(
    lambda g: g['file_size_mb'].sum() / g['avg_duration'].sum()
).reset_index(name='average_throughput_MBps')

print(throughput_by_executor)
# Out:
#   executor_type  average_throughput_MBps
# 0       process                 3.430104
# 1        thread                 1.612891
# /tmp/ipykernel_729/2687378280.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   throughput_by_executor = df.groupby('executor_type').apply(

# %%
failures_by_operation = df.groupby('operation')['fail_count'].sum().reset_index(name='total_failures')
print(failures_by_operation)
# Out:
#   operation  total_failures
# 0  download               8
# 1    upload               0

# %%
df['throughput'] = df['file_size_mb'] / df['avg_duration']

# %%
best_configs = df.sort_values(by='throughput', ascending=False).drop_duplicates(
    subset=['operation', 'file_size_mb', 'client_pool_size', 'executor_type']
)


for _, row in best_configs.iterrows():
    print(f"{row['operation']} - {row['file_size_mb']}MB - {row['client_pool_size']} clients - "
          f"{row['server_pool_size']} servers - {row['executor_type']} executor: "
          f"{row['throughput']:.2f} MB/s")
# Out:
# upload - 10MB - 1 clients - 5 servers - thread executor: 67.12 MB/s
# upload - 10MB - 1 clients - 5 servers - process executor: 62.58 MB/s
# download - 10MB - 1 clients - 5 servers - process executor: 53.85 MB/s
# upload - 10MB - 5 clients - 5 servers - process executor: 52.46 MB/s
# download - 10MB - 1 clients - 50 servers - thread executor: 49.71 MB/s
# download - 10MB - 5 clients - 50 servers - process executor: 43.66 MB/s
# upload - 50MB - 1 clients - 5 servers - thread executor: 30.86 MB/s
# upload - 50MB - 1 clients - 5 servers - process executor: 29.34 MB/s
# download - 50MB - 1 clients - 5 servers - thread executor: 29.15 MB/s
# download - 50MB - 1 clients - 5 servers - process executor: 27.26 MB/s
# upload - 50MB - 5 clients - 5 servers - process executor: 21.63 MB/s
# download - 50MB - 5 clients - 50 servers - process executor: 21.49 MB/s
# download - 100MB - 1 clients - 5 servers - thread executor: 19.17 MB/s
# ...

# %%
data = pd.read_csv('combined_output.csv')
data
# Out:
#      Unnamed: 0 operation  file_size_mb  client_pool_size  server_pool_size  \
# 0             0  download            10                 1                 1
# 1             1  download            10                 5                 1
# 2             2  download            10                50                 1
# 3             3  download            50                 1                 1
# 4             4  download            50                 5                 1
# ..          ...       ...           ...               ...               ...
# 103         103    upload            50                 5                50
# 104         104    upload            50                50                50
# 105         105    upload           100                 1                50
# 106         106    upload           100                 5                50
# 107         107    upload           100                50                50
#
# ...

# %%
col_index = data.columns.get_loc('avg_throughput')

# Drop 'avg_throughput'
data.drop(columns=['avg_throughput'], inplace=True)

# Calculate 'throughput'
throughput = data['file_size_mb'] / data['avg_duration']

# Insert 'throughput' at the same index
data.insert(col_index, 'throughput', throughput)

# %%
data
# Out:
#      Unnamed: 0 operation  file_size_mb  client_pool_size  server_pool_size  \
# 0             0  download            10                 1                 1
# 1             1  download            10                 5                 1
# 2             2  download            10                50                 1
# 3             3  download            50                 1                 1
# 4             4  download            50                 5                 1
# ..          ...       ...           ...               ...               ...
# 103         103    upload            50                 5                50
# 104         104    upload            50                50                50
# 105         105    upload           100                 1                50
# 106         106    upload           100                 5                50
# 107         107    upload           100                50                50
#
# ...

# %%
data.drop(columns=['median_throughput'], inplace=True)
data.drop(columns=['min_throughput'], inplace=True)
data.drop(columns=['max_throughput'], inplace=True)
data.drop(columns=['min_duration'], inplace=True)
data.drop(columns=['max_duration'], inplace=True)
data.drop(columns=['median_duration'], inplace=True)

# %%
data.to_csv("stress_test_output.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        108 non-null    int64
#  1   operation         108 non-null    object
#  2   file_size_mb      108 non-null    int64
#  3   client_pool_size  108 non-null    int64
#  4   server_pool_size  108 non-null    int64
#  5   executor_type     108 non-null    object
#  6   avg_duration      108 non-null    float64
#  7   throughput        108 non-null    float64
#  8   success_count     108 non-null    int64
#  9   fail_count        108 non-null    int64
#  10  success_rate      108 non-null    float64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 9.4+ KB

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %%
data
# Out:
#     operation  file_size_mb  client_pool_size  server_pool_size executor_type  \
# 0    download            10                 1                 1       process
# 1    download            10                 5                 1       process
# 2    download            10                50                 1       process
# 3    download            50                 1                 1       process
# 4    download            50                 5                 1       process
# ..        ...           ...               ...               ...           ...
# 103    upload            50                 5                50        thread
# 104    upload            50                50                50        thread
# 105    upload           100                 1                50        thread
# 106    upload           100                 5                50        thread
# 107    upload           100                50                50        thread
#
# ...

# %%
data.rename(columns={'avg_duration': 'duration'}, inplace=True)

# %%
data.drop(columns=['success_rate'], inplace=True)

# %%
data
# Out:
#     operation  file_size_mb  client_pool_size  server_pool_size executor_type  \
# 0    download            10                 1                 1       process
# 1    download            10                 5                 1       process
# 2    download            10                50                 1       process
# 3    download            50                 1                 1       process
# 4    download            50                 5                 1       process
# ..        ...           ...               ...               ...           ...
# 103    upload            50                 5                50        thread
# 104    upload            50                50                50        thread
# 105    upload           100                 1                50        thread
# 106    upload           100                 5                50        thread
# 107    upload           100                50                50        thread
#
# ...

# %%
data.rename(columns={'server_pool_size': 'server_pool'}, inplace=True)
data.rename(columns={'client_pool_size': 'client_pool'}, inplace=True)

# %%
data
# Out:
#     operation  file_size_mb  client_pool  server_pool executor_type  \
# 0    download            10            1            1       process
# 1    download            10            5            1       process
# 2    download            10           50            1       process
# 3    download            50            1            1       process
# 4    download            50            5            1       process
# ..        ...           ...          ...          ...           ...
# 103    upload            50            5           50        thread
# 104    upload            50           50           50        thread
# 105    upload           100            1           50        thread
# 106    upload           100            5           50        thread
# 107    upload           100           50           50        thread
#
#        duration  throughput  success_count  fail_count
# 0      0.191219   52.296164              1           0
# ...

# %%
data.rename(columns={'file_size_mb': 'volume'}, inplace=True)

# %%
data
# Out:
#     operation  volume  client_pool  server_pool executor_type    duration  \
# 0    download      10            1            1       process    0.191219
# 1    download      10            5            1       process    0.477270
# 2    download      10           50            1       process    4.563777
# 3    download      50            1            1       process    1.869165
# 4    download      50            5            1       process    5.480468
# ..        ...     ...          ...          ...           ...         ...
# 103    upload      50            5           50        thread    8.821735
# 104    upload      50           50           50        thread   91.580555
# 105    upload     100            1           50        thread    7.067302
# 106    upload     100            5           50        thread   29.493739
# 107    upload     100           50           50        thread  370.570190
#
#      throughput  success_count  fail_count
# ...

# %%
col = data.pop('executor_type')

data.insert(1, 'executor_type', col)

# %%
data
# Out:
#     operation executor_type  volume  client_pool  server_pool    duration  \
# 0    download       process      10            1            1    0.191219
# 1    download       process      10            5            1    0.477270
# 2    download       process      10           50            1    4.563777
# 3    download       process      50            1            1    1.869165
# 4    download       process      50            5            1    5.480468
# ..        ...           ...     ...          ...          ...         ...
# 103    upload        thread      50            5           50    8.821735
# 104    upload        thread      50           50           50   91.580555
# 105    upload        thread     100            1           50    7.067302
# 106    upload        thread     100            5           50   29.493739
# 107    upload        thread     100           50           50  370.570190
#
#      throughput  success_count  fail_count
# ...

# %%
data.to_csv("stress_test_output.csv")

# %%
data['duration'] = data['duration'].round(5)
data['throughput'] = data['throughput'].round(5)

# %%
data
# Out:
#     operation executor_type  volume  client_pool  server_pool   duration  \
# 0    download       process      10            1            1    0.19122
# 1    download       process      10            5            1    0.47727
# 2    download       process      10           50            1    4.56378
# 3    download       process      50            1            1    1.86916
# 4    download       process      50            5            1    5.48047
# ..        ...           ...     ...          ...          ...        ...
# 103    upload        thread      50            5           50    8.82173
# 104    upload        thread      50           50           50   91.58056
# 105    upload        thread     100            1           50    7.06730
# 106    upload        thread     100            5           50   29.49374
# 107    upload        thread     100           50           50  370.57019
#
#      throughput  success_count  fail_count
# 0      52.29616              1           0
# ...

# %%
data.to_csv("stress_test_output.csv")
